# %%
import pandas as pd

# %%
df = pd.read_csv('data/test/오존.csv')
df1 = pd.read_csv('data/test/평균기온.csv')
df2 = pd.read_csv('data/test/평균최고기온.csv')
df3 = pd.read_csv('data/test/평균최저기온.csv')
df4 = pd.read_csv('data/test/평균증기압.csv')

# %%
# df와 df1을 'STD_YYYYMM'과 'SIDO' 열을 기준으로 병합 (inner join)
result_df = pd.merge(df, df1, on=['STD_YYYYMM', 'SIDO'], how='inner')

# %%
# result_df와 df2을 'STD_YYYYMM'과 'SIDO' 열을 기준으로 병합 (inner join)
result_df = pd.merge(result_df, df2, on=['STD_YYYYMM', 'SIDO'], how='inner')

# %%
# result_df와 df3을 'STD_YYYYMM'과 'SIDO' 열을 기준으로 병합 (inner join)
result_df = pd.merge(result_df, df3, on=['STD_YYYYMM', 'SIDO'], how='inner')

# %%
# result_df와 df4을 'STD_YYYYMM'과 'SIDO' 열을 기준으로 병합 (inner join)
result_df = pd.merge(result_df, df4, on=['STD_YYYYMM', 'SIDO'], how='inner')

# %%
result_df.head(2)
# Out:
#     SIDO  STD_YYYYMM  AVG_오존 오존_BAD 오존0.06_BAD 오존0.1_BAD  평균기온  평균최고기온  \
# 0  서울특별시      201001   0.011      N          N         N  -4.5    -0.7
# 1  부산광역시      201001   0.021      N          N         N   3.0     7.7
#
#    평균최저기온  평균증기압
# 0    -8.1    3.1
# 1    -1.1    3.5

# %%
dd = result_df['STD_YYYYMM'].dtype

print(f"result_df['STD_YYYYMM'].dtype: {dd}")
# Out:
# result_df['STD_YYYYMM'].dtype: int64

# %%
# 그룹별로 NaN 값을 평균값으로 대체
result_df['AVG_오존'] = result_df.groupby(['SIDO', 'STD_YYYYMM'])['AVG_오존'].transform(lambda x: x.fillna(x.mean()))
# 필요한 경우, 여전히 NaN 값이 있는 경우에 대비해 전체 평균값으로 대체할 수도 있습니다
result_df['AVG_오존'] = result_df['AVG_오존'].fillna(result_df['AVG_오존'].mean())
result_df.isna().sum()
# Out:
# SIDO          0
# STD_YYYYMM    0
# AVG_오존        0
# 오존_BAD        0
# 오존0.06_BAD    0
# 오존0.1_BAD     0
# 평균기온          0
# 평균최고기온        0
# 평균최저기온        0
# 평균증기압         0
# dtype: int64

# %%
result_df.tail()
# Out:
#          SIDO  STD_YYYYMM  AVG_오존 오존_BAD 오존0.06_BAD 오존0.1_BAD  평균기온  평균최고기온  \
# 2491     충청남도      202212  0.0218      N          N         N  -2.2     3.1
# 2492     전라북도      202212  0.0230      N          N         N  -1.1     4.1
# 2493     전라남도      202212  0.0248      N          N         N   2.1     6.6
# 2494     경상북도      202212  0.0240      N          N         N  -1.1     4.1
# 2495  제주특별자치도      202212  0.0365      Y          N         N   6.8     9.8
#
#       평균최저기온  평균증기압
# 2491    -6.9    3.8
# 2492    -5.7    4.0
# 2493    -1.9    4.7
# 2494    -5.8    3.3
# 2495     4.0    6.6

# %%
# 'SIDO' 열에서 '서울특별시'인 행만 필터링
seoul_df = result_df[result_df['SIDO'] == '서울특별시']

# %%
# 'STD_YYYYMM'을 인덱스로 사용
seoul_df['STD_YYYYMM'] = pd.to_datetime(seoul_df['STD_YYYYMM'], format='%Y%m')
seoul_df = seoul_df.set_index('STD_YYYYMM')
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_5616\1799982633.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_df['STD_YYYYMM'] = pd.to_datetime(seoul_df['STD_YYYYMM'], format='%Y%m')

# %%
seoul_df.tail(2)
# Out:
#              SIDO  AVG_오존 오존_BAD 오존0.06_BAD 오존0.1_BAD  평균기온  평균최고기온  평균최저기온  \
# STD_YYYYMM
# 2022-11-01  서울특별시   0.018      N          N         N  10.0    15.4     5.6
# 2022-12-01  서울특별시   0.015      N          N         N  -2.8     1.7    -6.6
#
#             평균증기압
# STD_YYYYMM
# 2022-11-01    8.2
# 2022-12-01    3.1

# %%
# 원래의 'SIDO' 열 삭제
seoul_df.drop('SIDO', axis=1, inplace=True)

# %%
seoul_df.head()
# Out:
#             AVG_오존 오존_BAD 오존0.06_BAD 오존0.1_BAD  평균기온  평균최고기온  평균최저기온  평균증기압
# STD_YYYYMM
# 2010-01-01   0.011      N          N         N  -4.5    -0.7    -8.1    3.1
# 2010-02-01   0.016      N          N         N   1.4     4.9    -1.7    4.5
# 2010-03-01   0.024      N          N         N   4.3     8.1     0.5    4.9
# 2010-04-01   0.026      N          N         N   9.5    14.0     5.6    6.5
# 2010-05-01   0.030      Y          N         N  17.2    22.0    13.0   11.9

# %%
# 열 이름에 'BAD' 문자열을 포함하는 열을 찾아 삭제
seoul_df = seoul_df.loc[:, ~seoul_df.columns.str.contains('BAD')]

# %%
seoul_df.tail(10)
# Out:
#             AVG_오존  평균기온  평균최고기온  평균최저기온  평균증기압
# STD_YYYYMM
# 2022-03-01   0.028   7.7    12.7     3.2    6.7
# 2022-04-01   0.043  14.8    20.6    10.0    9.2
# 2022-05-01   0.049  19.1    25.0    13.9   12.0
# 2022-06-01   0.036  23.3    27.5    19.8   20.9
# 2022-07-01   0.037  27.3    31.0    24.2   27.7
# 2022-08-01   0.030  25.7    28.9    23.1   26.6
# 2022-09-01   0.031  22.4    27.2    18.2   18.2
# 2022-10-01   0.023  14.6    19.7    10.3   11.6
# 2022-11-01   0.018  10.0    15.4     5.6    8.2
# 2022-12-01   0.015  -2.8     1.7    -6.6    3.1

# %%
seoul_df.columns.value_counts()
# Out:
# AVG_오존    1
# 평균기온      1
# 평균최고기온    1
# 평균최저기온    1
# 평균증기압     1
# Name: count, dtype: int64

# %%
seoul_df
# Out:
#             AVG_오존  평균기온  평균최고기온  평균최저기온  평균증기압
# STD_YYYYMM
# 2010-01-01   0.011  -4.5    -0.7    -8.1    3.1
# 2010-02-01   0.016   1.4     4.9    -1.7    4.5
# 2010-03-01   0.024   4.3     8.1     0.5    4.9
# 2010-04-01   0.026   9.5    14.0     5.6    6.5
# 2010-05-01   0.030  17.2    22.0    13.0   11.9
# ...            ...   ...     ...     ...    ...
# 2022-08-01   0.030  25.7    28.9    23.1   26.6
# 2022-09-01   0.031  22.4    27.2    18.2   18.2
# 2022-10-01   0.023  14.6    19.7    10.3   11.6
# 2022-11-01   0.018  10.0    15.4     5.6    8.2
# 2022-12-01   0.015  -2.8     1.7    -6.6    3.1
#
# [156 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# 데이터셋 준비 (이미 원-핫 인코딩 및 NaN 처리 완료)
data = seoul_df.values

# 데이터 정규화
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# 데이터셋 분할
n_train = int(0.2 * len(data_scaled))
train_data = data_scaled[:n_train]
test_data = data_scaled[n_train:]
train_dates = seoul_df.index[:n_train]
test_dates = seoul_df.index[n_train:]

# 데이터셋 재구성
seq_len = 22  # 수치구성방법 총 데이터의수 20%가 최대치 (수치를 조정해서 모델 적중률 조정)
input_dim = train_data.shape[1]  # 입력 차원 (원-핫 인코딩된 열의 수)

trainX, trainY = [], []
testX, testY = [], []

for i in range(seq_len, len(train_data)):
    trainX.append(train_data[i-seq_len:i, :])
    trainY.append(train_data[i, 0])  # 첫 번째 열이 타겟 변수라고 가정

for i in range(seq_len, len(test_data)):
    testX.append(test_data[i-seq_len:i, :])
    testY.append(test_data[i, 0])

trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)

# LSTM 모델 구성
model = Sequential()
model.add(LSTM(128, input_shape=(seq_len, input_dim), return_sequences=True))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(1))  # 하나의 출력 뉴런

# 모델 컴파일 및 학습
model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
model.fit(trainX, trainY, epochs=70, batch_size=32, validation_split=0.1, verbose=1)

# 예측 및 역변환
prediction = model.predict(testX)
prediction_transformed = scaler.inverse_transform(np.concatenate((prediction, np.zeros((prediction.shape[0], data_scaled.shape[1]-1))), axis=1))[:,0]

testY_transformed = scaler.inverse_transform(np.concatenate((testY.reshape(-1,1), np.zeros((testY.shape[0], data_scaled.shape[1]-1))), axis=1))[:,0]
# Out:
# Epoch 1/70
# 1/1 [==============================] - 4s 4s/step - loss: 1.2146 - val_loss: 0.1699
# Epoch 2/70
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3759 - val_loss: 4.4949
# Epoch 3/70
# 1/1 [==============================] - 0s 49ms/step - loss: 1.0185 - val_loss: 0.6962
# Epoch 4/70
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7651 - val_loss: 0.4734
# Epoch 5/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1504 - val_loss: 0.4625
# Epoch 6/70
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2679 - val_loss: 0.5661
# Epoch 7/70
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2524 - val_loss: 0.7151
# Epoch 8/70
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1640 - val_loss: 0.9349
# Epoch 9/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0972 - val_loss: 1.3459
# Epoch 10/70
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0612 - val_loss: 2.0393
# Epoch 11/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0389 - val_loss: 2.7197
# Epoch 12/70
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0907 - val_loss: 2.7716
# Epoch 13/70
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0837 - val_loss: 2.2520
# Epoch 14/70
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0326 - val_loss: 1.6866
# Epoch 15/70
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0473 - val_loss: 1.5033
# Epoch 16/70
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0519 - val_loss: 1.6339
# Epoch 17/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0458 - val_loss: 1.8332
# Epoch 18/70
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0570 - val_loss: 1.9169
# Epoch 19/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0530 - val_loss: 1.8743
# Epoch 20/70
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0315 - val_loss: 1.8008
# Epoch 21/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0246 - val_loss: 1.8113
# Epoch 22/70
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0348 - val_loss: 1.9735
# Epoch 23/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0370 - val_loss: 2.2358
# Epoch 24/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0325 - val_loss: 2.4665
# Epoch 25/70
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0329 - val_loss: 2.5514
# Epoch 26/70
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0302 - val_loss: 2.4606
# Epoch 27/70
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0235 - val_loss: 2.2658
# Epoch 28/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0230 - val_loss: 2.0901
# Epoch 29/70
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0280 - val_loss: 2.0219
# Epoch 30/70
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0291 - val_loss: 2.0731
# Epoch 31/70
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0257 - val_loss: 2.2000
# Epoch 32/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0237 - val_loss: 2.3443
# Epoch 33/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0243 - val_loss: 2.4600
# Epoch 34/70
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0235 - val_loss: 2.5289
# Epoch 35/70
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0211 - val_loss: 2.5677
# Epoch 36/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0211 - val_loss: 2.6200
# Epoch 37/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0233 - val_loss: 2.7168
# Epoch 38/70
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0233 - val_loss: 2.8304
# Epoch 39/70
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0213 - val_loss: 2.8869
# Epoch 40/70
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0205 - val_loss: 2.8381
# Epoch 41/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0204 - val_loss: 2.7113
# Epoch 42/70
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0202 - val_loss: 2.5832
# Epoch 43/70
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0205 - val_loss: 2.5276
# Epoch 44/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0210 - val_loss: 2.5805
# Epoch 45/70
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0206 - val_loss: 2.7230
# Epoch 46/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0195 - val_loss: 2.8829
# Epoch 47/70
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0193 - val_loss: 2.9723
# Epoch 48/70
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0196 - val_loss: 2.9529
# Epoch 49/70
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0192 - val_loss: 2.8612
# Epoch 50/70
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0190 - val_loss: 2.7659
# Epoch 51/70
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0193 - val_loss: 2.7151
# Epoch 52/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0192 - val_loss: 2.7152
# Epoch 53/70
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0185 - val_loss: 2.7377
# Epoch 54/70
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0181 - val_loss: 2.7434
# Epoch 55/70
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0182 - val_loss: 2.7097
# Epoch 56/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0182 - val_loss: 2.6463
# Epoch 57/70
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0181 - val_loss: 2.5854
# Epoch 58/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0180 - val_loss: 2.5559
# Epoch 59/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0177 - val_loss: 2.5632
# Epoch 60/70
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0174 - val_loss: 2.5890
# Epoch 61/70
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0173 - val_loss: 2.6073
# Epoch 62/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0174 - val_loss: 2.6028
# Epoch 63/70
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0172 - val_loss: 2.5801
# Epoch 64/70
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0170 - val_loss: 2.5559
# Epoch 65/70
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0168 - val_loss: 2.5424
# Epoch 66/70
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0166 - val_loss: 2.5360
# Epoch 67/70
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0164 - val_loss: 2.5234
# Epoch 68/70
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0163 - val_loss: 2.4971
# Epoch 69/70
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0162 - val_loss: 2.4653
# Epoch 70/70
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0159 - val_loss: 2.4461
# 4/4 [==============================] - 1s 7ms/step

# %%
print(testX.shape)
# Out:
# (103, 22, 5)

# %%
print("Total data size:", len(data_scaled))
print("Training data size:", len(train_data))
print("Test data size:", len(test_data))
# Out:
# Total data size: 156
# Training data size: 31
# Test data size: 125

# %%
from sklearn.metrics import r2_score

# R² 값 계산
r_squared = r2_score(testY_transformed, prediction_transformed)

print("R-squared (Coefficient of Determination):", r_squared)
# Out:
# R-squared (Coefficient of Determination): 0.4956287525257209

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# MSE 및 MAE 계산
mse = mean_squared_error(testY_transformed, prediction_transformed)
mae = mean_absolute_error(testY_transformed, prediction_transformed)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
# Out:
# Mean Squared Error: 4.641185330043458e-05
# Mean Absolute Error: 0.005322721468349845

# %%
len(prediction_transformed), len(testY_transformed)
# Out:
# (103, 103)

# %%
print(f'prediction_transformed: {len(prediction_transformed)}, testY_transformed: {len(testY_transformed)}')
# Out:
# prediction_transformed: 103, testY_transformed: 103

# %%
test_dates
# Out:
# DatetimeIndex(['2012-08-01', '2012-09-01', '2012-10-01', '2012-11-01',
#                '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01',
#                '2013-04-01', '2013-05-01',
#                ...
#                '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01',
#                '2022-07-01', '2022-08-01', '2022-09-01', '2022-10-01',
#                '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', name='STD_YYYYMM', length=125, freq=None)

# %%
# 날짜 배열 조정: 끝에서 236개 데이터 포인트 선택
adjusted_test_dates = test_dates[-(len(testY_transformed)):]

# 결과 시각화
plt.figure(figsize=(14, 5))
plt.plot(adjusted_test_dates, testY_transformed, label='Actual')
plt.plot(adjusted_test_dates, prediction_transformed, label='Predicted', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Target Value')
plt.title('Actual vs Predicted')
plt.legend()
plt.show()

# %% [markdown]
# 그래프에 나타난 점이 중복되어 보이는 경우, 몇 가지 가능한 원인이 있을 수 있습니다:
#
# 데이터 중복: 같은 날짜에 대해 두 개 이상의 데이터 포인트가 있을 수 있습니다. 이것은 데이터셋 내의 중복된 행이나 데이터의 집계 방식에 오류가 있을 때 발생할 수 있습니다.
#
# 데이터 포인트의 겹침: 예측값과 실제값이 유사하여 그래프 상에서 겹쳐 보일 수 있습니다. 만약 실제값과 예측값이 거의 일치한다면, 두 선이 겹쳐져서 한 선처럼 보이지 않고, 별도의 점으로 나타날 수 있습니다.
#
# 시각화 코드: 시각화 코드가 같은 날짜에 대해 여러 점을 그리도록 구현되었을 수 있습니다. 예를 들어, plt.plot() 함수에 같은 날짜가 여러 번 나타날 경우 이런 현상이 발생할 수 있습니다.
#
# 데이터 전처리 오류: 데이터 전처리 과정에서 예측값이나 실제값 배열을 생성할 때 어떤 실수로 인해 데이터가 잘못된 위치에 할당되었을 수도 있습니다.
#
# 이 현상을 정확히 파악하려면 데이터와 시각화 코드를 자세히 검토할 필요가 있습니다. 일단 데이터프레임에 중복된 날짜가 있는지 확인하고, 이를 제거하는 것이 좋습니다. 중복을 확인하려면 다음과 같은 코드를 사용할 수 있습니다:

# %%
# 날짜별로 데이터가 중복되었는지 확인
duplicates = result_df.index.duplicated()
print("Number of duplicates in the index: ", duplicates.sum())
# Out:
# Number of duplicates in the index:  0

# %% [markdown]
# 함수에서 변화된 값을 가지지 않기때문에 계속 감소되거나 증가되는 증감이 없는 미래예측결과

# %%
def predict_future(model, initial_seq, future_steps, seq_len, input_dim):
    current_seq = initial_seq.copy()
    future_predictions = []

    for _ in range(future_steps):
        current_seq_reshaped = current_seq.reshape(1, seq_len, input_dim)
        next_prediction = model.predict(current_seq_reshaped)
        future_predictions.append(next_prediction[0, 0])

        # 다음 시퀀스 업데이트: 마지막 시퀀스 제거, 새로운 예측 추가
        current_seq = np.roll(current_seq, -input_dim, axis=0)
        current_seq[-1, :] = np.zeros(input_dim)
        current_seq[-1, 0] = next_prediction[0, 0]

    return future_predictions

# 함수 사용
future_steps = 200
latest_sequence = testX[-1]  # 가장 최근 시퀀스
future_predictions = predict_future(model, latest_sequence, future_steps, seq_len, input_dim)


# 예측된 값들을 원래 데이터셋과 동일한 차원으로 확장
extended_predictions = np.zeros((len(future_predictions), data_scaled.shape[1]))
extended_predictions[:, 0] = future_predictions

# 역변환을 통해 원래 스케일로 변환
future_predictions_transformed = scaler.inverse_transform(extended_predictions)[:, 0]

# 미래 날짜 생성
future_dates = pd.date_range(start=test_dates[-1], periods=future_steps + 1)[1:]

# 결과 시각화
plt.figure(figsize=(14, 5))
plt.plot(future_dates, future_predictions_transformed, label='Future Predictions')
plt.xlabel('Date')
plt.ylabel('Predicted Value')
plt.title('Future Value Predictions')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
