# %%
import requests
from datetime import datetime, timedelta
from pprint import pprint

# %%
# 측정소별 실시간 측정정보 조회 (매시 15분 내외 업데이트)
base_url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty"
with open('keys/에어코리아api.txt') as file:
    service_key = file.read()       # 발급받은 에어코리아 API 키 입력

# %%
# 웹 요청시 같이 전달될 데이터 = 요청 메시지
params = {
        'serviceKey' : service_key,
        'returnType' : 'JSON',
        'numOfRows' : 30,
        'pageNo' : 1,
        'stationName' : "대신동", # 시도 이름
        'dataTerm' : 'DAILY',
        'ver' : "1.4" # 오퍼레이션 버전
    }

res = requests.get(url=base_url , params=params)
# print(res.status_code, type(res.text), res.url)
# print()
# print(res.text)

# 응답 데이터 정리
from pprint import pprint  # 구조있는 데이터를 더 편하게 보여줌
data = res.json() # json.loads(res.text)와 같은 기능
data = data['response']['body']['items']
pprint(data)
# Out:
# [{'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 13:00',
#   'khaiGrade': '1',
#   'khaiValue': '50',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.013',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.030',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '15',
#   'pm10Value24': '17',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '7',
#   'pm25Value24': '8',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 12:00',
#   'khaiGrade': '1',
#   'khaiValue': '50',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.012',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.030',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '17',
#   'pm10Value24': '18',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '4',
#   'pm25Value24': '9',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 11:00',
#   'khaiGrade': '1',
#   'khaiValue': '43',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.013',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.026',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '20',
#   'pm10Value24': '17',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '7',
#   'pm25Value24': '10',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 10:00',
#   'khaiGrade': '1',
#   'khaiValue': '38',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.014',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.023',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '20',
#   'pm10Value24': '17',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '9',
#   'pm25Value24': '11',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 09:00',
#   'khaiGrade': '1',
#   'khaiValue': '40',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.016',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.020',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '14',
#   'pm10Value24': '15',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '9',
#   'pm25Value24': '12',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 08:00',
#   'khaiGrade': '1',
#   'khaiValue': '40',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.013',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.023',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '13',
#   'pm10Value24': '16',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '10',
#   'pm25Value24': '12',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 07:00',
#   'khaiGrade': '1',
#   'khaiValue': '43',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.010',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.026',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '15',
#   'pm10Value24': '16',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '15',
#   'pm25Value24': '12',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 06:00',
#   'khaiGrade': '1',
#   'khaiValue': '48',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.007',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.029',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '11',
#   'pm10Value24': '17',
#   'pm25Flag': '통신장애',
#   'pm25Grade': '1',
#   'pm25Grade1h': None,
#   'pm25Value': '-',
#   'pm25Value24': '12',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 05:00',
#   'khaiGrade': '2',
#   'khaiValue': '53',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.005',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.033',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '17',
#   'pm10Value24': '18',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '10',
#   'pm25Value24': '11',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 04:00',
#   'khaiGrade': '2',
#   'khaiValue': '53',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.005',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.034',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '13',
#   'pm10Value24': '20',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '11',
#   'pm25Value24': '12',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 03:00',
#   'khaiGrade': '2',
#   'khaiValue': '54',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.005',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.035',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '17',
#   'pm10Value24': '21',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '13',
#   'pm25Value24': '12',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 02:00',
#   'khaiGrade': '2',
#   'khaiValue': '55',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.004',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.036',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '19',
#   'pm10Value24': '20',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '11',
#   'pm25Value24': '11',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-25 01:00',
#   'khaiGrade': '2',
#   'khaiValue': '53',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.005',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.034',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '2',
#   'pm10Value': '32',
#   'pm10Value24': '21',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '13',
#   'pm25Value24': '11',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 24:00',
#   'khaiGrade': '2',
#   'khaiValue': '53',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.006',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.033',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '21',
#   'pm10Value24': '18',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '14',
#   'pm25Value24': '11',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 23:00',
#   'khaiGrade': '1',
#   'khaiValue': '47',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.012',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.028',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '18',
#   'pm10Value24': '18',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '10',
#   'pm25Value24': '10',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.003',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 22:00',
#   'khaiGrade': '1',
#   'khaiValue': '38',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.018',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.023',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '22',
#   'pm10Value24': '18',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '15',
#   'pm25Value24': '10',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.4',
#   'dataTime': '2023-11-24 21:00',
#   'khaiGrade': '1',
#   'khaiValue': '38',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.019',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.023',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '17',
#   'pm10Value24': '17',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '14',
#   'pm25Value24': '9',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 20:00',
#   'khaiGrade': '1',
#   'khaiValue': '45',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.017',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.027',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '18',
#   'pm10Value24': '17',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '11',
#   'pm25Value24': '7',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 19:00',
#   'khaiGrade': '1',
#   'khaiValue': '43',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.017',
#   'o3Flag': None,
#   'o3Grade': '1',
#   'o3Value': '0.026',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '18',
#   'pm10Value24': '16',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '11',
#   'pm25Value24': '6',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 18:00',
#   'khaiGrade': '2',
#   'khaiValue': '51',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.015',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.031',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '19',
#   'pm10Value24': '15',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '6',
#   'pm25Value24': '5',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 17:00',
#   'khaiGrade': '2',
#   'khaiValue': '56',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.011',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.037',
#   'pm10Flag': None,
#   'pm10Grade': '1',
#   'pm10Grade1h': '1',
#   'pm10Value': '14',
#   'pm10Value24': '14',
#   'pm25Flag': None,
#   'pm25Grade': '1',
#   'pm25Grade1h': '1',
#   'pm25Value': '4',
#   'pm25Value24': '5',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 16:00',
#   'khaiGrade': None,
#   'khaiValue': '-',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.007',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.042',
#   'pm10Flag': None,
#   'pm10Grade': None,
#   'pm10Grade1h': '1',
#   'pm10Value': '14',
#   'pm10Value24': '-',
#   'pm25Flag': None,
#   'pm25Grade': None,
#   'pm25Grade1h': '1',
#   'pm25Value': '2',
#   'pm25Value24': '-',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'},
#  {'coFlag': None,
#   'coGrade': '1',
#   'coValue': '0.3',
#   'dataTime': '2023-11-24 15:00',
#   'khaiGrade': None,
#   'khaiValue': '-',
#   'mangName': '도시대기',
#   'no2Flag': None,
#   'no2Grade': '1',
#   'no2Value': '0.006',
#   'o3Flag': None,
#   'o3Grade': '2',
#   'o3Value': '0.042',
#   'pm10Flag': None,
#   'pm10Grade': None,
#   'pm10Grade1h': '1',
#   'pm10Value': '8',
#   'pm10Value24': '-',
#   'pm25Flag': None,
#   'pm25Grade': None,
#   'pm25Grade1h': '1',
#   'pm25Value': '2',
#   'pm25Value24': '-',
#   'so2Flag': None,
#   'so2Grade': '1',
#   'so2Value': '0.002',
#   'stationCode': '221281',
#   'stationName': '대신동'}]

# %%
# 완성코드

def get_air_quality(station_Name):
    
    # 웹 요청시 같이 전달될 데이터 = 요청 메시지
    params = {
        'serviceKey' : service_key,
        'returnType' : 'JSON',
        'numOfRows' : 30,
        'pageNo' : 1,
        'stationName' : station_Name, # 시도 이름
        'dataTerm' : 'DAILY',
        'ver' : "1.4" # 오퍼레이션 버전
    }

    res = requests.get(url=base_url , params=params)

    # 응답 데이터 정리
    from pprint import pprint  # 구조있는 데이터를 더 편하게 보여줌
    data = res.json() # json.loads(res.text)와 같은 기능
    data = data['response']['body']['items']
    
    # 데이터를 날짜와 시간에 대한 기준으로 정렬
    sorted_data = sorted(data, key=lambda x: x['dataTime'], reverse=True)

    # 최신 데이터 선택
    latest_data = sorted_data[0]
    
    # 최종 데이터 생성
    results = {
        '날짜': latest_data['dataTime'],
        '이름': latest_data['stationName'],
        '측정망 정보': latest_data['mangName'],
        '아황산가스 농도': latest_data['so2Value'] + "ppm",
        '일산화탄소 농도': latest_data['coValue'] + "ppm",
        '오존 농도': latest_data['o3Value'] + "ppm",
        '이산화질소 농도': latest_data['no2Value'] + "ppm",
        '미세먼지(PM10) 농도': latest_data['pm10Value'] + "ug/m³",
        '초미세먼지(PM2.5) 농도': latest_data['pm25Value'] + "ug/m³"
    }

    # pprint(results)
    return results
    
# 테스트 코드
if __name__ == "__main__":
    print(get_air_quality('대신동'))
# Out:
# {'날짜': '2023-11-25 13:00', '이름': '대신동', '측정망 정보': '도시대기', '아황산가스 농도': '0.002ppm', '일산화탄소 농도': '0.3ppm', '오존 농도': '0.030ppm', '이산화질소 농도': '0.013ppm', '미세먼지(PM10) 농도': '15ug/m³', '초미세먼지(PM2.5) 농도': '7ug/m³'}
