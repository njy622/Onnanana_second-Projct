# %%
import pandas as pd
import matplotlib.pyplot as plt
from draw_map import  BORDER_LINES, drawKorea, drawKoreaMinus

pop = pd.read_csv('data/카토그램.csv', encoding='utf-8')

drawKorea('격자 Y', pop, 'Blues')

# %%
def draw_choropleth_map(map_raw, df):
    map_raw.stack()[:10]
    map_df = pd.DataFrame(map_raw.stack())
    map_df.reset_index(inplace=True)
    map_df.columns = ['y', 'x', 'ID']
    df = pd.merge(df, map_df)
    plt.show()
    
draw_choropleth_map()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\WorkSpace\Onnanana_second-Projct\01.심민준\기상청\06.test copy.ipynb 셀 2 line 9
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/Onnanana_second-Projct/01.%EC%8B%AC%EB%AF%BC%EC%A4%80/%EA%B8%B0%EC%83%81%EC%B2%AD/06.test%20copy.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>     df = pd.merge(df, map_df)
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/Onnanana_second-Projct/01.%EC%8B%AC%EB%AF%BC%EC%A4%80/%EA%B8%B0%EC%83%81%EC%B2%AD/06.test%20copy.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>     plt.show()
# ----> <a href='vscode-notebook-cell:/d%3A/WorkSpace/Onnanana_second-Projct/01.%EC%8B%AC%EB%AF%BC%EC%A4%80/%EA%B8%B0%EC%83%81%EC%B2%AD/06.test%20copy.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> draw_choropleth_map()
#
# TypeError: draw_choropleth_map() missing 2 required positional arguments: 'map_raw' and 'df'
