# %% [markdown]
# ### 영등포구 소재 지하철역

# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('data/영등포소재 지하철역2.csv')
df
# Out:
#         이름                             주소         위도          경도
# 0     영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659
# 1     신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719
# 2      당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731
# 3     여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485
# 4   영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=13) #Center position
for i in df.index:
    folium.Marker(
        location=[df.위도[i],df.경도[i]],    # WGS84 좌표계: 위도(latitude), 경도(longitude)
        tooltip=df.이름[i],
        popup=folium.Popup(df.주소[i], max_width=200)
    ).add_to(map)

title_html = '<h3 align="center" style="font-size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c590a15263150ec619733a0dab79a29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c590a15263150ec619733a0dab79a29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c590a15263150ec619733a0dab79a29 = L.map(
#                 &quot;map_5c590a15263150ec619733a0dab79a29&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b340cadc167e0a9d62a7cf798495db1d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c590a15263150ec619733a0dab79a29);
#
#
#             var marker_f878d39192ae79b9e1884c0ac6d9bed2 = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_5c590a15263150ec619733a0dab79a29);
#
#
#         var popup_2b6f14a6bf719bd35557587e640080e2 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_29b194727634090301c6db810675502b = $(`&lt;div id=&quot;html_29b194727634090301c6db810675502b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_2b6f14a6bf719bd35557587e640080e2.setContent(html_29b194727634090301c6db810675502b);
#
#
#
#         marker_f878d39192ae79b9e1884c0ac6d9bed2.bindPopup(popup_2b6f14a6bf719bd35557587e640080e2)
#         ;
#
#
#
#
#             marker_f878d39192ae79b9e1884c0ac6d9bed2.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_55446359536c2918ae9d5b3fa89ba1fb = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_5c590a15263150ec619733a0dab79a29);
#
#
#         var popup_8e234175417687e7c83db30d6c960621 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b2814edd5b1921e54f2868cfcf6fd72b = $(`&lt;div id=&quot;html_b2814edd5b1921e54f2868cfcf6fd72b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_8e234175417687e7c83db30d6c960621.setContent(html_b2814edd5b1921e54f2868cfcf6fd72b);
#
#
#
#         marker_55446359536c2918ae9d5b3fa89ba1fb.bindPopup(popup_8e234175417687e7c83db30d6c960621)
#         ;
#
#
#
#
#             marker_55446359536c2918ae9d5b3fa89ba1fb.bindTooltip(
#                 `&lt;div&gt;
#                       신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_98a25640dc55c1c6dd4622388e5c66ec = L.marker(
#                 [37.534956866618, 126.90273071003],
#                 {}
#             ).addTo(map_5c590a15263150ec619733a0dab79a29);
#
#
#         var popup_5089c952ca1b7cc01d6deb62de1b100d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_02ed72359dbbef03fb9566b7533c36d3 = $(`&lt;div id=&quot;html_02ed72359dbbef03fb9566b7533c36d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 당산로 229 (당산동6가)&lt;/div&gt;`)[0];
#                 popup_5089c952ca1b7cc01d6deb62de1b100d.setContent(html_02ed72359dbbef03fb9566b7533c36d3);
#
#
#
#         marker_98a25640dc55c1c6dd4622388e5c66ec.bindPopup(popup_5089c952ca1b7cc01d6deb62de1b100d)
#         ;
#
#
#
#
#             marker_98a25640dc55c1c6dd4622388e5c66ec.bindTooltip(
#                 `&lt;div&gt;
#                       당산역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5644f4477906df175f943e95455971d4 = L.marker(
#                 [37.5218423045786, 126.924484687694],
#                 {}
#             ).addTo(map_5c590a15263150ec619733a0dab79a29);
#
#
#         var popup_ba364df67f58a0108512259a26fc97ed = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b2219ebbc7ceba5e6507f0ec8084fda1 = $(`&lt;div id=&quot;html_b2219ebbc7ceba5e6507f0ec8084fda1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 여의나루로 지하40 (여의도동)&lt;/div&gt;`)[0];
#                 popup_ba364df67f58a0108512259a26fc97ed.setContent(html_b2219ebbc7ceba5e6507f0ec8084fda1);
#
#
#
#         marker_5644f4477906df175f943e95455971d4.bindPopup(popup_ba364df67f58a0108512259a26fc97ed)
#         ;
#
#
#
#
#             marker_5644f4477906df175f943e95455971d4.bindTooltip(

# %%
df['color'] = ['red', 'blue', 'green', 'violet', 'orange']
df
# Out:
#         이름                             주소         위도          경도   color
# 0     영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659     red
# 1     신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719    blue
# 2      당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731   green
# 3     여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485  violet
# 4   영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627  orange

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14) #Center position
for i in df.index:
    folium.Circle(
        location=[df.위도[i],df.경도[i]],    # WGS84 좌표계: 위도(latitude), 경도(longitude)
        tooltip=df.이름[i],
        popup=folium.Popup(df.주소[i], max_width=200),
        radius=100, color=df.color[i], fill=True,
    ).add_to(map)
    folium.Marker(
        location=[df.위도[i],df.경도[i]],   
        icon = folium.DivIcon(icon_size=(80,20), icon_anchor=(20,0),
                              html=f'<span style="font-size: 10pt">{df.이름[i]}</span>')
    ).add_to(map)
folium.Marker(
        location=[df.위도.mean(), df.경도.mean()],
        icon=folium.CustomIcon('data/pushpin-vector-1504119.jpg', icon_size=(30,30))   
)

title_html = '<h3 align="center" style="font-size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be1edfbd971083d1ccffec20b588eb14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be1edfbd971083d1ccffec20b588eb14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be1edfbd971083d1ccffec20b588eb14 = L.map(
#                 &quot;map_be1edfbd971083d1ccffec20b588eb14&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e123495114021a8985a6074c4b93d22 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_be1edfbd971083d1ccffec20b588eb14);
#
#
#             var circle_439e09a03ce14f648e0b962703b28f3f = L.circle(
#                 [37.5164625580995, 126.906658750671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be1edfbd971083d1ccffec20b588eb14);
#
#
#         var popup_859e72b3de3fe38dcfbfffac482147bf = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_057a62414050817a1cc8a4c830af76ec = $(`&lt;div id=&quot;html_057a62414050817a1cc8a4c830af76ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_859e72b3de3fe38dcfbfffac482147bf.setContent(html_057a62414050817a1cc8a4c830af76ec);
#
#
#
#         circle_439e09a03ce14f648e0b962703b28f3f.bindPopup(popup_859e72b3de3fe38dcfbfffac482147bf)
#         ;
#
#
#
#
#             circle_439e09a03ce14f648e0b962703b28f3f.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_623020b8154f3052890cd0489bc40766 = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_be1edfbd971083d1ccffec20b588eb14);
#
#
#             var div_icon_12c811548062bde78a552b84b3c58e9e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&quot;font-size: 10pt\&quot;\u003e\uc601\ub4f1\ud3ec\uc5ed\u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [20, 0], &quot;iconSize&quot;: [80, 20]});
#             marker_623020b8154f3052890cd0489bc40766.setIcon(div_icon_12c811548062bde78a552b84b3c58e9e);
#
#
#             var circle_d6986b5ce573e6005be4295d87c5a0b0 = L.circle(
#                 [37.5070842748567, 126.884718686628],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_be1edfbd971083d1ccffec20b588eb14);
#
#
#         var popup_02479725fe2dea67d3338f08ef43dd24 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_f3a7e57916103359ec728b39bf7f4880 = $(`&lt;div id=&quot;html_f3a7e57916103359ec728b39bf7f4880&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_02479725fe2dea67d3338f08ef43dd24.setContent(html_f3a7e57916103359ec728b39bf7f4880);
#
#
#
#         circle_d6986b5ce573e6005be4295d87c5a0b0.bindPopup(popup_02479725fe2dea67d3338f08ef43dd24)
#         ;
#
#
#
#
#             circle_d6986b5ce573e6005be4295d87c5a0b0.bindTooltip(
#                 `&lt;div&gt;
#                       신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6311124db99c9487609b86c75210e71d = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_be1edfbd971083d1ccffec20b588eb14);
#
#
#             var div_icon_3b054c72dddc181294a7318dab54494e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&
