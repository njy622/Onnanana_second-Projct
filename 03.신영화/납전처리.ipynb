# %%
import pandas as pd

# %%
df = pd.read_csv('data/납 월별 도시별 대기오염도.csv',encoding='ansi')

# %%
df.head(3)
# Out:
#     구분  항목  단위  2013.01 월  2013.02 월  2013.03 월  2013.04 월  2013.05 월  \
# 0  대흥동  Pb NaN     0.0839     0.0959     0.1009     0.0940     0.1116
# 1  성수동  Pb NaN     0.0846     0.0420     0.1215     0.1385     0.1506
# 2  마포구  Pb NaN        NaN        NaN        NaN        NaN        NaN
#
#    2013.06 월  2013.07 월  ...  2022.06 월  2022.07 월  2022.08 월  2022.09 월  \
# 0     0.0676     0.0866  ...        NaN        NaN        NaN        NaN
# 1     0.1120     0.0342  ...        NaN        NaN        NaN        NaN
# 2        NaN        NaN  ...      .0034      .0119      .0196      .0074
#
#    2022.10 월  2022.11 월  2022.12 월  2023.01 월  2023.02 월  Unnamed: 125
# 0        NaN        NaN        NaN        NaN        NaN           NaN
# 1        NaN        NaN        NaN        NaN        NaN           NaN
# 2      .0132      .0203      .0237      .0324     .04326           NaN
#
# [3 rows x 126 columns]

# %%
long_df = df.melt(id_vars=['구분', '항목','단위'], 
                  var_name='STD_YYYYMM', 
                  value_name='납')

# %%
long_df.head(3)
# Out:
#     구분  항목  단위 STD_YYYYMM       납
# 0  대흥동  Pb NaN  2013.01 월  0.0839
# 1  성수동  Pb NaN  2013.01 월  0.0846
# 2  마포구  Pb NaN  2013.01 월     NaN

# %%
df = long_df.drop(['구분', '항목', '단위'], axis=1)
df.head(3)
# Out:
#   STD_YYYYMM       납
# 0  2013.01 월  0.0839
# 1  2013.01 월  0.0846
# 2  2013.01 월     NaN

# %%
df['STD_YYYYMM'] = df['STD_YYYYMM'].str.replace('월', '')
df.head(3)
# Out:
#   STD_YYYYMM       납
# 0   2013.01   0.0839
# 1   2013.01   0.0846
# 2   2013.01      NaN

# %%
transposed_df = df.transpose()
transposed_df.head(3)
# Out:
#                0         1         2         3         4         5      \
# STD_YYYYMM  2013.01   2013.01   2013.01   2013.01   2013.01   2013.01
# 납             0.0839    0.0846       NaN       NaN       NaN    0.0673
#
#                6         7         8         9      ...         13766  \
# STD_YYYYMM  2013.01   2013.01   2013.01   2013.01   ...  Unnamed: 125
# 납                NaN     0.109    0.1022    0.0836  ...           NaN
#
#                    13767         13768         13769         13770  \
# STD_YYYYMM  Unnamed: 125  Unnamed: 125  Unnamed: 125  Unnamed: 125
# 납                    NaN           NaN           NaN           NaN
#
#                    13771         13772         13773         13774  \
# STD_YYYYMM  Unnamed: 125  Unnamed: 125  Unnamed: 125  Unnamed: 125
# 납                    NaN           NaN           NaN           NaN
#
#                    13775
# STD_YYYYMM  Unnamed: 125
# 납                    NaN
#
# [2 rows x 13776 columns]

# %%
df = transposed_df.rename(columns=transposed_df.iloc[0])        #첫번째 행을 column으로 지정
df.head(3)
# Out:
#             2013.01   2013.01   2013.01   2013.01   2013.01   2013.01   \
# STD_YYYYMM  2013.01   2013.01   2013.01   2013.01   2013.01   2013.01
# 납             0.0839    0.0846       NaN       NaN       NaN    0.0673
#
#             2013.01   2013.01   2013.01   2013.01   ...  Unnamed: 125  \
# STD_YYYYMM  2013.01   2013.01   2013.01   2013.01   ...  Unnamed: 125
# 납                NaN     0.109    0.1022    0.0836  ...           NaN
#
#             Unnamed: 125  Unnamed: 125  Unnamed: 125  Unnamed: 125  \
# STD_YYYYMM  Unnamed: 125  Unnamed: 125  Unnamed: 125  Unnamed: 125
# 납                    NaN           NaN           NaN           NaN
#
#             Unnamed: 125  Unnamed: 125  Unnamed: 125  Unnamed: 125  \
# STD_YYYYMM  Unnamed: 125  Unnamed: 125  Unnamed: 125  Unnamed: 125
# 납                    NaN           NaN           NaN           NaN
#
#             Unnamed: 125
# STD_YYYYMM  Unnamed: 125
# 납                    NaN
#
# [2 rows x 13776 columns]

# %%
df = df.drop(df.index[0])        #첫번째 행을 삭제한다
df
# Out:
#   2013.01  2013.01  2013.01  2013.01  2013.01  2013.01  2013.01  2013.01   \
# 납   0.0839   0.0846      NaN      NaN      NaN   0.0673      NaN    0.109
#
#   2013.01  2013.01   ... Unnamed: 125 Unnamed: 125 Unnamed: 125 Unnamed: 125  \
# 납   0.1022   0.0836  ...          NaN          NaN          NaN          NaN
#
#   Unnamed: 125 Unnamed: 125 Unnamed: 125 Unnamed: 125 Unnamed: 125  \
# 납          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 125
# 납          NaN
#
# [1 rows x 13776 columns]

# %%
df.to_csv('data/납_2.csv', index=True)
